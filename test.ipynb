# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])

# %%
print(arr)
# Out:
# [1 2 3 4]

# %%
print(np.mean(arr))
# Out:
# 2.5

# %%
print(np.sum(arr))
# Out:
# 10

# %%
print(arr**2)
# Out:
# [ 1  4  9 16]
